# %% [markdown]
# <a href="https://colab.research.google.com/github/kalex066/RetailSales_DataAnalysis_Numpy/blob/main/notebooks/Core_RetailSales_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# En esta primera parte del proyecto, se realizará un análisis preliminar del dataset de Kaggle titulado «Retail Sales Dataset» (2023-2024), utilizando NumPy con el objetivo de familiarizarse con los datos y realizar operaciones básicas de manipulación y análisis.
#
# Este dataset contiene información detallada sobre las ventas diarias de diferentes productos en una tienda.

# %% [markdown]
# # Carga de Datos con NumPy

# %%
import numpy as np

def cargar_datos(ruta_archivo):
    # Carga los datos del archivo CSV utilizando NumPy
    datos = np.genfromtxt('/content/retail_sales_dataset.csv', delimiter=',', skip_header=1)
    return datos

if __name__ == "__main__":
    ruta_archivo = '/content/retail_sales_dataset.csv'
    datos = cargar_datos(ruta_archivo)
    print(datos)
# Out:
# [[   1.   nan   nan ...    3.   50.  150.]
#  [   2.   nan   nan ...    2.  500. 1000.]
#  [   3.   nan   nan ...    1.   30.   30.]
#  ...
#  [ 998.   nan   nan ...    4.   25.  100.]
#  [ 999.   nan   nan ...    3.   50.  150.]
#  [1000.   nan   nan ...    4.   30.  120.]]

# %% [markdown]
# # Preprocesamiento de Datos

# %%
# Dimensiones del array
print(datos.shape)
# Out:
# (1000, 9)

# %%
# Numero total de elementos en el array
print(datos.size)
# Out:
# 9000

# %%
# Numero de dimensiones del array
print(datos.ndim)
# Out:
# 2
